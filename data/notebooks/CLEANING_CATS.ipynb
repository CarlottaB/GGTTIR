# %% [markdown]
# ## Short notebook: combining dataframes on categories

# %%
#import libraries
import pandas as pd
import re
import xlsxwriter

# %%
#set file-paths
file_path_categories = '../data_base/Categories_over_time.xlsx'

file_path_thinktanks = '../data_base/CLEAN_THINKTANKS.xlsx'

# %%
#import category-datasets
regions_category_df = pd.read_excel(file_path_categories,sheet_name='regions')
research_category_df = pd.read_excel(file_path_categories,sheet_name='research_areas_clean')
special_category_df = pd.read_excel(file_path_categories,sheet_name='special_categories_clean')

# %%
#import think-tank datasets
regions_tt_df = pd.read_excel(file_path_thinktanks,sheet_name='regions')
research_tt_df = pd.read_excel(file_path_thinktanks,sheet_name='research_areas')
special_tt_df = pd.read_excel(file_path_thinktanks,sheet_name='special_categories')

# %%
research_category_df['Category'] = research_category_df['Category'].str.lower().str.strip()
research_tt_df['Category'] = research_tt_df['Category'].str.lower().str.strip()

# %%
research_tt_df.head()
# Out:
#    Rank                                     origin_tt_name  \
# 0     1                        brookings institution (usa)
# 1     2           overseas development institute (odi)  uk
# 2     3                 council on foreign relations (usa)
# 3     4                             rand corporation (usa)
# 4     5  woodrow wilson international center for schola...
#
#                            Category  Year         country parenthesis  \
# 0  top 10 international development  2008   United States   ['(usa)']
# 1  top 10 international development  2008  United Kingdom   ['(odi)']
# 2  top 10 international development  2008   United States   ['(usa)']
# 3  top 10 international development  2008   United States   ['(usa)']
# 4  top 10 international development  2008   United States   ['(usa)']
#
#                                            clean_tt
# 0                             brookings institution
# 1                 overseas development institute
# 2                      council on foreign relations
# 3                                  rand corporation
# 4  woodrow wilson international center for scholars

# %%
#merge datasets
cleand_regions_tt = pd.merge(regions_tt_df,regions_category_df[['Category','Category2']],left_on='Category',right_on='Category',how='left')

cleand_research_tt = pd.merge(research_tt_df,research_category_df[['Category','Category2']],left_on='Category',right_on='Category',how='left')

cleand_special_tt = pd.merge(special_tt_df,special_category_df[['Category','Category2']],left_on='Category',right_on='Category',how='left')

# %%
#cleand_regions_tt.head()

# %%
#rename cateories:
cleand_regions_tt.rename(columns={'Category2':'cleaned_category'},inplace=True)

cleand_research_tt.rename(columns={'Category2':'cleaned_category'},inplace=True)

cleand_special_tt.rename(columns={'Category2':'cleaned_category'},inplace=True)

# %%
#check for empty new categories

#cleand_regions_tt[cleand_regions_tt['cleaned_category'].isnull()]
cleand_research_tt[cleand_research_tt['cleaned_category'].isnull()]
#cleand_special_tt[cleand_special_tt['cleaned_category'].isnull()]
#len(cleand_research_tt)
# Out:
#       Rank                                     origin_tt_name  \
# 0        1                        brookings institution (usa)
# 1        2           overseas development institute (odi)  uk
# 2        3                 council on foreign relations (usa)
# 3        4                             rand corporation (usa)
# 4        5  woodrow wilson international center for schola...
# 5        6               institute of development studies  uk
# 6        7                 center for global development  usa
# 7        8  international food policy research institute  usa
# 8        9              german development institute  germany
# 9       10                   international policy network  uk
# 10      10           atlas economic research foundation (usa)
# 11      10  international development research centre (can...
# 12       1                        brookings institution (usa)
# 13       2         national bureau of economic research (usa)
# 14       3                             rand corporation (usa)
# 15       4                              urban institute (usa)
# 16       5                american enterprise institute (usa)
# 17       6  council on foreign relations global health pro...
# 18       7                               cato institute (usa)
# 19       8                          fraser institute (canada)
# 6643  top domestic health affairs think tanks  2018            Belgium
# 6644  top domestic health affairs think tanks  2018              India
# 6645  top domestic health affairs think tanks  2018             Mexico
# 6646  top domestic health affairs think tanks  2018              China
# 6647  top domestic health affairs think tanks  2018             Canada
# 6648  top domestic health affairs think tanks  2018      United States
# 6649  top domestic health affairs think tanks  2018     United Kingdom
# 6650  top domestic health affairs think tanks  2018      United States
# 6651  top domestic health affairs think tanks  2018          Argentina
# 6652  top domestic health affairs think tanks  2018              India
# 6653  top domestic health affairs think tanks  2018      United States
# 6654  top domestic health affairs think tanks  2018              China
# 6655  top domestic health affairs think tanks  2018      United States
# 6656  top domestic health affairs think tanks  2018           Tanzania
# 6657  top domestic health affairs think tanks  2018              India
# 6658  top domestic health affairs think tanks  2018  Republic of Korea
# 6659  top domestic health affairs think tanks  2018              China
# 6660  top domestic health affairs think tanks  2018             France
# 6661  top domestic health affairs think tanks  2018         Mozambique
# 6662  top domestic health affairs think tanks  2018      United States
# 6663  top domestic health affairs think tanks  2018              Italy
# 6664  top domestic health affairs think tanks  2018      United States
# 6665  top domestic health affairs think tanks  2018              India
# 6666  top domestic health affairs think tanks  2018      United States
# 6667  top domestic health affairs think tanks  2018        Netherlands
#
#                               parenthesis  \
# 0                               ['(usa)']
# 1                               ['(odi)']
# 2                               ['(usa)']
# 3                               ['(usa)']
# 4                               ['(usa)']
# 5                                      []
# 6                                      []
# 7                                      []
# 8                                      []
# 9                                      []
# 10                              ['(usa)']
# 11                           ['(canada)']
# 12                              ['(usa)']
# 13                              ['(usa)']
# 14                              ['(usa)']
# 15                              ['(usa)']
# 16                              ['(usa)']
# 17                                     []
# 18                              ['(usa)']
# 19                           ['(canada)']
# 20                                     []
# 21                                     []
# 22                                     []
# 23                              ['(usa)']
# 24                              ['(usa)']
# 25                                     []
# 26                              ['(usa)']
# 27                                     []
# 28                                     []
# 29                     ['(rff)', '(usa)']
# ...                                   ...
# 6638               ['(zew)', '(germany)']
# 6639                ['(atps)', '(kenya)']
# 6640         ['(ldi)', '(united states)']
# 6641         ['(cfr)', '(united states)']
# 6642             ['(ips)', '(sri lanka)']
# 6643                        ['(belgium)']
# 6644                 ['(ccs)', '(india)']
# 6645                         ['(mexico)']
# 6646              ['(cnhdrc)', '(china)']
# 6647                         ['(canada)']
# 6648                      ['(australia)']
# 6649      ['(cchsr)', '(united kingdom)']
# 6650         ['(ced)', '(united states)']
# 6651          ['(clacso)', '(argentina)']
# 6652                 ['(fdr)', '(india)']
# 6653                  ['(united states)']
# 6654                          ['(china)']
# 6655                  ['(united states)']
# 6656              ['(ihi)', '(tanzania)']
# 6657                          ['(india)']
# 6658  ['(kihasa)', '(republic of korea)']
# 6659                          ['(china)']
# 6660                         ['(france)']
# 6661           ['(cism)', '(mozambique)']
# 6662                  ['(united states)']
# 6663                          ['(italy)']
# 6664        ['(ncpa)', '(united states)']
# 6665                 ['(orf)', '(india)']
# 6666       ['(jhsph)', '(united states)']
# 6667                    ['(netherlands)']
#
#                                                clean_tt cleaned_category
# 0                                 brookings institution              NaN
# 1                     overseas development institute                 NaN
# 2                          council on foreign relations              NaN
# 3                                      rand corporation              NaN
# 4      woodrow wilson international center for scholars              NaN
# 5                    institute of development studies                NaN
# 6                       center for global development                NaN
# 7        international food policy research institute                NaN
# 8                        german development institute                NaN
# 9                        international policy network                NaN
# 10                   atlas economic research foundation              NaN
# 11            international development research centre              NaN
# 12                                brookings institution              NaN
# 13                 national bureau of economic research              NaN
# 14                                     rand corporation              NaN
# 15                                      urban institute              NaN
# 16                        american enterprise institute              NaN
# 17    council on foreign relations global health pro...              NaN
# 18                                       cato institute              NaN
# 19                                     fraser institute              NaN
# 20                      center for global development                NaN
# 21                                            civitas                NaN
# 22                national center for policy analysis                NaN
# 23           carnegie endowment for international peace              NaN
# 24                                brookings institution              NaN
# 25                        world resources institute,usa              NaN
# 26                                 worldwatch institute              NaN
# 27                pew center on global climate change                NaN
# 28    belfer center for science and int'l affairs, k...              NaN
# 29                             resources for the future              NaN
# ...                                                 ...              ...
# 6638              center for european economic research              NaN
# 6639          african technology policy studies network              NaN
# 6640        leonard davis institute of health economics              NaN
# 6641  council on foreign relations, global health pr...              NaN
# 6642           institute of policy studies of sri lanka              NaN
# 6643                                            bruegel              NaN
# 6644                           centre for civil society              NaN
# 6645      centro de investigacion y docencia economicas              NaN
# 6646  china national health development research center              NaN
# 6647               canadian centre for health economics              NaN
# 6648                                  grattan institute              NaN
# 6649                           health services research              NaN
# 6650                 committee for economic development              NaN
# 6651       consejo latinoamericano de ciencias sociales              NaN
# 6652                  foundation for democratic reforms              NaN
# 6653                                    galen institute              NaN
# 6654                            global health institute              NaN
# 6655                                goldwater institute              NaN
# 6656                           ifakara health institute              NaN
# 6657                                    india institute              NaN
# 6658      korea institute for health and social affairs              NaN
# 6659                           our hong kong foundation              NaN
# 6660                                 institut montaigne              NaN
# 6661          centro internacional em saude de manhiã§a              NaN
# 6662                               independent insitute              NaN
# 6663                                   action institute              NaN
# 6664                national center for policy analysis              NaN
# 6665                       observer research foundation              NaN
# 6666                     public health research centers              NaN
# 6667                               quid novi foundation              NaN
#
# [2579 rows x 8 columns]

# %%
cleand_regions_tt.head()
# Out:
#    Rank                              origin_tt_name  \
# 0     1       brookings institution (united states)
# 1     2                council on foreign relations
# 2     3  carnegie endowment for international peace
# 3     4                            rand corporation
# 4     5                         heritage foundation
#
#                            Category  Year        Country          parenthesis  \
# 0  Top 30 Think Tanks United States  2008  United States  ['(united states)']
# 1  Top 30 Think Tanks United States  2008  United States                   []
# 2  Top 30 Think Tanks United States  2008  United States                   []
# 3  Top 30 Think Tanks United States  2008  United States                   []
# 4  Top 30 Think Tanks United States  2008  United States                   []
#
#                                      clean_tt  \
# 0                       brookings institution
# 1                council on foreign relations
# 2  carnegie endowment for international peace
# 3                            rand corporation
# 4                         heritage foundation
#
#                        cleaned_category
# 0  Top Think Tanks in the United States
# 1  Top Think Tanks in the United States
# 2  Top Think Tanks in the United States
# 3  Top Think Tanks in the United States
# 4  Top Think Tanks in the United States

# %%
writer = pd.ExcelWriter('../results/tts_conslidated_categories.xlsx', engine='xlsxwriter')
cleand_regions_tt.to_excel(writer,sheet_name='regions',index=False)
cleand_special_tt.to_excel(writer,sheet_name='special',index=False)
cleand_research_tt.to_excel(writer,sheet_name='research_areas',index=False)
writer.save()
